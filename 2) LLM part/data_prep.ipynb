# %%
from encoder import encode

# %%
from pathlib import Path

DATA_DIR = Path("../dataset/audio/")
dataset = list(DATA_DIR.glob("*.mid"))

dataset
# Out:
# [WindowsPath('../dataset/audio/11.mid'),
#  WindowsPath('../dataset/audio/1584morzcondma.mid'),
#  WindowsPath('../dataset/audio/1763wamk465a.mid'),
#  WindowsPath('../dataset/audio/1786gpk136a.mid'),
#  WindowsPath('../dataset/audio/1787gpk136b.mid'),
#  WindowsPath('../dataset/audio/1788gpk136c.mid'),
#  WindowsPath('../dataset/audio/1996rondoflute.mid'),
#  WindowsPath('../dataset/audio/2017mozk299no1.mid'),
#  WindowsPath('../dataset/audio/2018mozk299no2.mid'),
#  WindowsPath('../dataset/audio/2019mozk299no3.mid'),
#  WindowsPath('../dataset/audio/2021mozk191no1.mid'),
#  WindowsPath('../dataset/audio/2022mozk191no2.mid'),
#  WindowsPath('../dataset/audio/2023mozk191no3.mid'),
#  WindowsPath('../dataset/audio/2024panos3no1.mid'),
#  WindowsPath('../dataset/audio/2025pianos3no2.mid'),
#  WindowsPath('../dataset/audio/2026pianos3no3.mid'),
#  WindowsPath('../dataset/audio/2029rondoSteven2.mid'),
#  WindowsPath('../dataset/audio/2249phantasieSteven.mid'),
#  WindowsPath('../dataset/audio/2250adagioSteven.mid'),
#  WindowsPath('../dataset/audio/2294rondomozSteven.mid'),
#  WindowsPath('../dataset/audio/2344serenadeinbb.mid'),
#  WindowsPath('../dataset/audio/240ALC~1.mid'),
#  WindowsPath('../dataset/audio/241Brondo.mid'),
#  WindowsPath('../dataset/audio/2421mozartfunnya.mid'),
#  WindowsPath('../dataset/audio/242Adag_bm.mid'),
#  WindowsPath('../dataset/audio/244cosifn2t.mid'),
#  WindowsPath('../dataset/audio/245div1.mid'),
#  WindowsPath('../dataset/audio/264diesirae.mid'),
#  WindowsPath('../dataset/audio/2677mozartspring.mid'),
#  WindowsPath('../dataset/audio/269Fantsy_c.mid'),
#  WindowsPath('../dataset/audio/29.mid'),
#  WindowsPath('../dataset/audio/2916requm1.mid'),
#  WindowsPath('../dataset/audio/2917requm2.mid'),
#  WindowsPath('../dataset/audio/2918requm4.mid'),
#  WindowsPath('../dataset/audio/3467minuetrdtevenritchie.mid'),
#  WindowsPath('../dataset/audio/351fandm.mid'),
#  WindowsPath('../dataset/audio/36.mid'),
#  WindowsPath('../dataset/audio/362sonat_c1.mid'),
#  WindowsPath('../dataset/audio/363sonat_c2.mid'),
#  WindowsPath('../dataset/audio/364sonat_c3.mid'),
#  WindowsPath('../dataset/audio/366fantsy_c.mid'),
#  WindowsPath('../dataset/audio/367sonat_a1.mid'),
#  WindowsPath('../dataset/audio/368sonat_a2.mid'),
#  WindowsPath('../dataset/audio/369sonat_a3.mid'),
#  WindowsPath('../dataset/audio/3954gloriainrstevenritchie.mid'),
#  WindowsPath('../dataset/audio/4127mozsymphstevenritchie.mid'),
#  WindowsPath('../dataset/audio/426mozfig.mid'),
#  WindowsPath('../dataset/audio/4316mk387m4.mid'),
#  WindowsPath('../dataset/audio/4317mk387m3.mid'),
#  WindowsPath('../dataset/audio/4318mk387m2.mid'),
#  WindowsPath('../dataset/audio/4319mk387m1.mid'),
#  WindowsPath('../dataset/audio/4321_duett.mid'),
#  WindowsPath('../dataset/audio/4498rmps04orig.mid'),
#  WindowsPath('../dataset/audio/4499rmps03orig.mid'),
#  WindowsPath('../dataset/audio/4500rmps02orig.mid'),
#  WindowsPath('../dataset/audio/4501rmps01orig.mid'),
#  WindowsPath('../dataset/audio/4502rmps05.mid'),
#  WindowsPath('../dataset/audio/4503rmps06.mid'),
#  WindowsPath('../dataset/audio/495p141ck.mid'),
#  WindowsPath('../dataset/audio/496p142ck.mid'),
#  WindowsPath('../dataset/audio/497p143ck.mid'),
#  WindowsPath('../dataset/audio/57811meno1.mid'),
#  WindowsPath('../dataset/audio/57911meno10.mid'),
#  WindowsPath('../dataset/audio/630alconspi.mid'),
#  WindowsPath('../dataset/audio/648almolto.mid'),
#  WindowsPath('../dataset/audio/659andante.mid'),
#  WindowsPath('../dataset/audio/72.mid'),
#  WindowsPath('../dataset/audio/confuta.mid'),
#  WindowsPath('../dataset/audio/cosifn2t.mid'),
#  WindowsPath('../dataset/audio/jm_mozdi.mid'),
#  WindowsPath('../dataset/audio/k452.mid'),
#  WindowsPath('../dataset/audio/krebs.mid'),
#  WindowsPath('../dataset/audio/lenozzedifigarostevenritchie.mid'),
#  WindowsPath('../dataset/audio/magflute.mid'),
#  WindowsPath('../dataset/audio/marriagefigarostevenritchie.mid'),
#  WindowsPath('../dataset/audio/mfig.mid'),
#  WindowsPath('../dataset/audio/MozartMagicFluteOverKV620e.mid'),
#  WindowsPath('../dataset/audio/mozartromancestev.mid'),
#  WindowsPath('../dataset/audio/mozeine.mid'),
#  WindowsPath('../dataset/audio/mozk175a.mid'),
#  WindowsPath('../dataset/audio/mozk175b.mid'),
#  WindowsPath('../dataset/audio/mozk175c.mid'),
#  WindowsPath('../dataset/audio/mozk211a.mid'),
#  WindowsPath('../dataset/audio/mozk211b.mid'),
#  WindowsPath('../dataset/audio/mozk211c.mid'),
#  WindowsPath('../dataset/audio/mozk216a.mid'),
#  WindowsPath('../dataset/audio/mozk216b.mid'),
#  WindowsPath('../dataset/audio/mozk216c.mid'),
#  WindowsPath('../dataset/audio/mozk218a.mid'),
#  WindowsPath('../dataset/audio/mozk218b.mid'),
#  WindowsPath('../dataset/audio/mozk218c.mid'),
#  WindowsPath('../dataset/audio/mozk219a.mid'),
#  WindowsPath('../dataset/audio/mozk219b.mid'),
#  WindowsPath('../dataset/audio/mozk219c.mid'),
#  WindowsPath('../dataset/audio/mozk246a.mid'),
#  WindowsPath('../dataset/audio/mozk246b.mid'),
#  WindowsPath('../dataset/audio/mozk246c.mid'),
#  WindowsPath('../dataset/audio/mozk281a.mid'),
#  WindowsPath('../dataset/audio/mozk281b.mid'),
#  WindowsPath('../dataset/audio/mozk281c.mid'),
#  WindowsPath('../dataset/audio/mozk299a.mid'),
#  WindowsPath('../dataset/audio/mozk299b.mid'),
#  WindowsPath('../dataset/audio/mozk299c.mid'),
#  WindowsPath('../dataset/audio/mozk309a.mid'),
#  WindowsPath('../dataset/audio/mozk309b.mid'),
#  WindowsPath('../dataset/audio/mozk309c.mid'),
#  WindowsPath('../dataset/audio/mozk310a.mid'),
#  WindowsPath('../dataset/audio/mozk310b.mid'),
#  WindowsPath('../dataset/audio/mozk310c.mid'),
#  WindowsPath('../dataset/audio/mozk311a.mid'),
#  WindowsPath('../dataset/audio/mozk311b.mid'),
#  WindowsPath('../dataset/audio/mozk311c.mid'),
#  WindowsPath('../dataset/audio/mozk313a.mid'),
#  WindowsPath('../dataset/audio/mozk313b.mid'),
#  WindowsPath('../dataset/audio/mozk313c.mid'),
#  WindowsPath('../dataset/audio/mozk331a.mid'),
#  WindowsPath('../dataset/audio/mozk331b.mid'),
#  WindowsPath('../dataset/audio/mozk331c.mid'),
#  WindowsPath('../dataset/audio/mozk332a.mid'),
#  WindowsPath('../dataset/audio/mozk332b.mid'),
#  WindowsPath('../dataset/audio/mozk332c.mid'),
#  WindowsPath('../dataset/audio/mozk333a.mid'),
#  WindowsPath('../dataset/audio/mozk333b.mid'),
#  WindowsPath('../dataset/audio/mozk333c.mid'),
#  WindowsPath('../dataset/audio/mozk450a.mid'),
#  WindowsPath('../dataset/audio/mozk450b.mid'),
#  WindowsPath('../dataset/audio/mozk450c.mid'),
#  WindowsPath('../dataset/audio/mozk453a.mid'),
#  WindowsPath('../dataset/audio/mozk453b.mid'),
#  WindowsPath('../dataset/audio/mozk453c.mid'),
#  WindowsPath('../dataset/audio/mozk466a.mid'),
#  WindowsPath('../dataset/audio/mozk466b.mid'),
#  WindowsPath('../dataset/audio/mozk466c.mid'),
#  WindowsPath('../dataset/audio/mozk467a.mid'),
#  WindowsPath('../dataset/audio/mozk467b.mid'),
#  WindowsPath('../dataset/audio/mozk467c.mid'),
#  WindowsPath('../dataset/audio/mozk488a.mid'),
#  WindowsPath('../dataset/audio/mozk488b.mid'),
#  WindowsPath('../dataset/audio/mozk488c.mid'),
#  WindowsPath('../dataset/audio/mozk545a.mid'),
#  WindowsPath('../dataset/audio/mozk545b.mid'),
#  WindowsPath('../dataset/audio/mozk545c.mid'),
#  WindowsPath('../dataset/audio/mozk622a.mid'),
#  WindowsPath('../dataset/audio/mozk622b.mid'),
#  WindowsPath('../dataset/audio/mozk622c.mid'),
#  WindowsPath('../dataset/audio/mozsq1.mid'),
#  WindowsPath('../dataset/audio/moz_k191.mid'),
#  WindowsPath('../dataset/audio/moz_k299.mid'),
#  WindowsPath('../dataset/audio/mtmoz1.mid'),
#  WindowsPath('../dataset/audio/mzflqnar.mid'),
#  WindowsPath('../dataset/audio/mz_311_1.mid'),
#  WindowsPath('../dataset/audio/mz_311_2.mid'),
#  WindowsPath('../dataset/audio/mz_311_3.mid'),
#  WindowsPath('../dataset/audio/mz_330_1.mid'),
#  WindowsPath('../dataset/audio/mz_330_2.mid'),
#  WindowsPath('../dataset/audio/mz_330_3.mid'),
#  WindowsPath('../dataset/audio/mz_331_1.mid'),
#  WindowsPath('../dataset/audio/mz_331_2.mid'),
#  WindowsPath('../dataset/audio/mz_331_3.mid'),
#  WindowsPath('../dataset/audio/mz_332_1.mid'),
#  WindowsPath('../dataset/audio/mz_332_2.mid'),
#  WindowsPath('../dataset/audio/mz_332_3.mid'),
#  WindowsPath('../dataset/audio/mz_333_1.mid'),
#  WindowsPath('../dataset/audio/mz_333_2.mid'),
#  WindowsPath('../dataset/audio/mz_333_3.mid'),
#  WindowsPath('../dataset/audio/mz_545_1.mid'),
#  WindowsPath('../dataset/audio/mz_545_2.mid'),
#  WindowsPath('../dataset/audio/mz_545_3.mid'),
#  WindowsPath('../dataset/audio/mz_570_1.mid'),
#  WindowsPath('../dataset/audio/mz_570_2.mid'),
#  WindowsPath('../dataset/audio/mz_570_3.mid'),
#  WindowsPath('../dataset/audio/pianoconcertono21inCk4671andante.mid'),
#  WindowsPath('../dataset/audio/pianoconcertono21inCk4672andante .mid'),
#  WindowsPath('../dataset/audio/pianosonatano13inCk3331allegros.mid'),
#  WindowsPath('../dataset/audio/pianosonatano13inCk3332andante.mid'),
#  WindowsPath('../dataset/audio/pianosonatano13inCk3333allegretto.mid'),
#  WindowsPath('../dataset/audio/sym40-1.mid'),
#  WindowsPath('../dataset/audio/Symphony No. 41 in C, K.551, Jupiter.mid'),
#  WindowsPath('../dataset/audio/symphony_183_1_(c)ishii.mid'),
#  WindowsPath('../dataset/audio/symphony_183_2_(c)ishii.mid'),
#  WindowsPath('../dataset/audio/symphony_183_3_(c)ishii.mid'),
#  WindowsPath('../dataset/audio/themagicflutestevenritchie.mid')]

# %%
for i, mid in enumerate(dataset):
    print(f"==== Processing {i+1}/{len(dataset)} ====")
    encode(str(mid), print_details=False)
# Out:
# ==== Processing 1/182 ====
# Processing MIDI file: 11.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 11.86 minutes
# =======================================================
# Data saved to ../dataset/text\11_2.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 2/182 ====
# Processing MIDI file: 1584morzcondma.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 9.59 minutes
# =======================================================
# Data saved to ../dataset/text\1584morzcondma_2.txt
# with bpm = 78.0
# =======================================================
#
#
# ==== Processing 3/182 ====
# Processing MIDI file: 1763wamk465a.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 4
# Note: 1 instruments may use duplicate programs
# Estimated length: 13.53 minutes
# =======================================================
# Data saved to ../dataset/text\1763wamk465a_2.txt
# with bpm = 145.0
# =======================================================
#
#
# ==== Processing 4/182 ====
# Processing MIDI file: 1786gpk136a.mid
# -------------------------------------------------------
# Score title: None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 for i, mid in enumerate(dataset):
#       2     print(f"==== Processing {i+1}/{len(dataset)} ====")
# ----> 3     encode(str(mid), print_details=False)
#
# File d:\Codess & Projects\Project Mozart\2) LLM part\encoder.py:407, in encode(midi_path, output_dir, print_details)
#     404 # Process MIDI
#     405 try:
#     406     # Get data and bpm
# --> 407     data = midi_to_dict(midi_path, print_details)
#     408     bpm = get_bpm_from_midi(midi_path)
#     410     # Get accurate duration - FIXED
#
# File d:\Codess & Projects\Project Mozart\2) LLM part\encoder.py:347, in midi_to_dict(midi_path, print_details)
#     345 note_count = 0
#     346 for el in part.recurse().notesAndRests:
# --> 347     token = note_to_token(el)
#     348     if token:
#     349         tokens.append(token)
#
# File d:\Codess & Projects\Project Mozart\2) LLM part\encoder.py:34, in note_to_token(n)
#      31 """Convert a music21 Note/Chord/Rest into token 'NAME_DURATION'."""
#      33 # Map the note/chord duration to its symbolic representation
# ---> 34 dur = dur_map_to_symbol.get(round(n.duration.quarterLength, 2),
#      35                             str(n.duration.quarterLength))
#      37 if isinstance(n, note.Note):
#      38     # Single note: "C4_q"
#      39     return f"{n.nameWithOctave}_{dur}"
#
# File ~\AppData\Local\Programs\Python\Python310\lib\fractions.py:633, in Fraction.__round__(self, ndigits)
#     629 # See _operator_fallbacks.forward to check that the results of
#     630 # these operations will always be Fraction and therefore have
#     631 # round().
#     632 if ndigits > 0:
# --> 633     return Fraction(round(self * shift), shift)
#     634 else:
#     635     return Fraction(round(self / shift) * shift)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\fractions.py:358, in Fraction._operator_fallbacks.<locals>.forward(a, b)
#     356 def forward(a, b):
#     357     if isinstance(b, (int, Fraction)):
# --> 358         return monomorphic_operator(a, b)
#     359     elif isinstance(b, float):
#     360         return fallback_operator(float(a), b)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\fractions.py:483, in Fraction._mul(a, b)
#     479     return Fraction(t // g2, s * (db // g2), _normalize=False)
#     481 __sub__, __rsub__ = _operator_fallbacks(_sub, operator.sub)
# --> 483 def _mul(a, b):
#     484     """a * b"""
#     485     na, da = a.numerator, a.denominator
#
# KeyboardInterrupt:
