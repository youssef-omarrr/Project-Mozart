# %%
from encoder import encode

# %%
from pathlib import Path

DATA_DIR = Path("../dataset/audio/")
dataset = list(DATA_DIR.glob("*.mid"))

dataset
# Out:
# [WindowsPath('../dataset/audio/11.mid'),
#  WindowsPath('../dataset/audio/1584morzcondma.mid'),
#  WindowsPath('../dataset/audio/1763wamk465a.mid'),
#  WindowsPath('../dataset/audio/1786gpk136a.mid'),
#  WindowsPath('../dataset/audio/1787gpk136b.mid'),
#  WindowsPath('../dataset/audio/1788gpk136c.mid'),
#  WindowsPath('../dataset/audio/1996rondoflute.mid'),
#  WindowsPath('../dataset/audio/2017mozk299no1.mid'),
#  WindowsPath('../dataset/audio/2018mozk299no2.mid'),
#  WindowsPath('../dataset/audio/2019mozk299no3.mid'),
#  WindowsPath('../dataset/audio/2021mozk191no1.mid'),
#  WindowsPath('../dataset/audio/2022mozk191no2.mid'),
#  WindowsPath('../dataset/audio/2023mozk191no3.mid'),
#  WindowsPath('../dataset/audio/2024panos3no1.mid'),
#  WindowsPath('../dataset/audio/2025pianos3no2.mid'),
#  WindowsPath('../dataset/audio/2026pianos3no3.mid'),
#  WindowsPath('../dataset/audio/2029rondoSteven2.mid'),
#  WindowsPath('../dataset/audio/2249phantasieSteven.mid'),
#  WindowsPath('../dataset/audio/2250adagioSteven.mid'),
#  WindowsPath('../dataset/audio/2294rondomozSteven.mid'),
#  WindowsPath('../dataset/audio/2344serenadeinbb.mid'),
#  WindowsPath('../dataset/audio/240ALC~1.mid'),
#  WindowsPath('../dataset/audio/241Brondo.mid'),
#  WindowsPath('../dataset/audio/2421mozartfunnya.mid'),
#  WindowsPath('../dataset/audio/242Adag_bm.mid'),
#  WindowsPath('../dataset/audio/244cosifn2t.mid'),
#  WindowsPath('../dataset/audio/245div1.mid'),
#  WindowsPath('../dataset/audio/264diesirae.mid'),
#  WindowsPath('../dataset/audio/2677mozartspring.mid'),
#  WindowsPath('../dataset/audio/269Fantsy_c.mid'),
#  WindowsPath('../dataset/audio/29.mid'),
#  WindowsPath('../dataset/audio/2916requm1.mid'),
#  WindowsPath('../dataset/audio/2917requm2.mid'),
#  WindowsPath('../dataset/audio/2918requm4.mid'),
#  WindowsPath('../dataset/audio/3467minuetrdtevenritchie.mid'),
#  WindowsPath('../dataset/audio/351fandm.mid'),
#  WindowsPath('../dataset/audio/36.mid'),
#  WindowsPath('../dataset/audio/362sonat_c1.mid'),
#  WindowsPath('../dataset/audio/363sonat_c2.mid'),
#  WindowsPath('../dataset/audio/364sonat_c3.mid'),
#  WindowsPath('../dataset/audio/366fantsy_c.mid'),
#  WindowsPath('../dataset/audio/367sonat_a1.mid'),
#  WindowsPath('../dataset/audio/368sonat_a2.mid'),
#  WindowsPath('../dataset/audio/369sonat_a3.mid'),
#  WindowsPath('../dataset/audio/3954gloriainrstevenritchie.mid'),
#  WindowsPath('../dataset/audio/4127mozsymphstevenritchie.mid'),
#  WindowsPath('../dataset/audio/426mozfig.mid'),
#  WindowsPath('../dataset/audio/4316mk387m4.mid'),
#  WindowsPath('../dataset/audio/4317mk387m3.mid'),
#  WindowsPath('../dataset/audio/4318mk387m2.mid'),
#  WindowsPath('../dataset/audio/4319mk387m1.mid'),
#  WindowsPath('../dataset/audio/4321_duett.mid'),
#  WindowsPath('../dataset/audio/4498rmps04orig.mid'),
#  WindowsPath('../dataset/audio/4499rmps03orig.mid'),
#  WindowsPath('../dataset/audio/4500rmps02orig.mid'),
#  WindowsPath('../dataset/audio/4501rmps01orig.mid'),
#  WindowsPath('../dataset/audio/4502rmps05.mid'),
#  WindowsPath('../dataset/audio/4503rmps06.mid'),
#  WindowsPath('../dataset/audio/495p141ck.mid'),
#  WindowsPath('../dataset/audio/496p142ck.mid'),
#  WindowsPath('../dataset/audio/497p143ck.mid'),
#  WindowsPath('../dataset/audio/57811meno1.mid'),
#  WindowsPath('../dataset/audio/57911meno10.mid'),
#  WindowsPath('../dataset/audio/630alconspi.mid'),
#  WindowsPath('../dataset/audio/648almolto.mid'),
#  WindowsPath('../dataset/audio/659andante.mid'),
#  WindowsPath('../dataset/audio/72.mid'),
#  WindowsPath('../dataset/audio/confuta.mid'),
#  WindowsPath('../dataset/audio/cosifn2t.mid'),
#  WindowsPath('../dataset/audio/jm_mozdi.mid'),
#  WindowsPath('../dataset/audio/k452.mid'),
#  WindowsPath('../dataset/audio/krebs.mid'),
#  WindowsPath('../dataset/audio/lenozzedifigarostevenritchie.mid'),
#  WindowsPath('../dataset/audio/magflute.mid'),
#  WindowsPath('../dataset/audio/marriagefigarostevenritchie.mid'),
#  WindowsPath('../dataset/audio/mfig.mid'),
#  WindowsPath('../dataset/audio/MozartMagicFluteOverKV620e.mid'),
#  WindowsPath('../dataset/audio/mozartromancestev.mid'),
#  WindowsPath('../dataset/audio/mozeine.mid'),
#  WindowsPath('../dataset/audio/mozk175a.mid'),
#  WindowsPath('../dataset/audio/mozk175b.mid'),
#  WindowsPath('../dataset/audio/mozk175c.mid'),
#  WindowsPath('../dataset/audio/mozk211a.mid'),
#  WindowsPath('../dataset/audio/mozk211b.mid'),
#  WindowsPath('../dataset/audio/mozk211c.mid'),
#  WindowsPath('../dataset/audio/mozk216a.mid'),
#  WindowsPath('../dataset/audio/mozk216b.mid'),
#  WindowsPath('../dataset/audio/mozk216c.mid'),
#  WindowsPath('../dataset/audio/mozk218a.mid'),
#  WindowsPath('../dataset/audio/mozk218b.mid'),
#  WindowsPath('../dataset/audio/mozk218c.mid'),
#  WindowsPath('../dataset/audio/mozk219a.mid'),
#  WindowsPath('../dataset/audio/mozk219b.mid'),
#  WindowsPath('../dataset/audio/mozk219c.mid'),
#  WindowsPath('../dataset/audio/mozk246a.mid'),
#  WindowsPath('../dataset/audio/mozk246b.mid'),
#  WindowsPath('../dataset/audio/mozk246c.mid'),
#  WindowsPath('../dataset/audio/mozk281a.mid'),
#  WindowsPath('../dataset/audio/mozk281b.mid'),
#  WindowsPath('../dataset/audio/mozk281c.mid'),
#  WindowsPath('../dataset/audio/mozk299a.mid'),
#  WindowsPath('../dataset/audio/mozk299b.mid'),
#  WindowsPath('../dataset/audio/mozk299c.mid'),
#  WindowsPath('../dataset/audio/mozk309a.mid'),
#  WindowsPath('../dataset/audio/mozk309b.mid'),
#  WindowsPath('../dataset/audio/mozk309c.mid'),
#  WindowsPath('../dataset/audio/mozk310a.mid'),
#  WindowsPath('../dataset/audio/mozk310b.mid'),
#  WindowsPath('../dataset/audio/mozk310c.mid'),
#  WindowsPath('../dataset/audio/mozk311a.mid'),
#  WindowsPath('../dataset/audio/mozk311b.mid'),
#  WindowsPath('../dataset/audio/mozk311c.mid'),
#  WindowsPath('../dataset/audio/mozk313a.mid'),
#  WindowsPath('../dataset/audio/mozk313b.mid'),
#  WindowsPath('../dataset/audio/mozk313c.mid'),
#  WindowsPath('../dataset/audio/mozk331a.mid'),
#  WindowsPath('../dataset/audio/mozk331b.mid'),
#  WindowsPath('../dataset/audio/mozk331c.mid'),
#  WindowsPath('../dataset/audio/mozk332a.mid'),
#  WindowsPath('../dataset/audio/mozk332b.mid'),
#  WindowsPath('../dataset/audio/mozk332c.mid'),
#  WindowsPath('../dataset/audio/mozk333a.mid'),
#  WindowsPath('../dataset/audio/mozk333b.mid'),
#  WindowsPath('../dataset/audio/mozk333c.mid'),
#  WindowsPath('../dataset/audio/mozk450a.mid'),
#  WindowsPath('../dataset/audio/mozk450b.mid'),
#  WindowsPath('../dataset/audio/mozk450c.mid'),
#  WindowsPath('../dataset/audio/mozk453a.mid'),
#  WindowsPath('../dataset/audio/mozk453b.mid'),
#  WindowsPath('../dataset/audio/mozk453c.mid'),
#  WindowsPath('../dataset/audio/mozk466a.mid'),
#  WindowsPath('../dataset/audio/mozk466b.mid'),
#  WindowsPath('../dataset/audio/mozk466c.mid'),
#  WindowsPath('../dataset/audio/mozk467a.mid'),
#  WindowsPath('../dataset/audio/mozk467b.mid'),
#  WindowsPath('../dataset/audio/mozk467c.mid'),
#  WindowsPath('../dataset/audio/mozk488a.mid'),
#  WindowsPath('../dataset/audio/mozk488b.mid'),
#  WindowsPath('../dataset/audio/mozk488c.mid'),
#  WindowsPath('../dataset/audio/mozk545a.mid'),
#  WindowsPath('../dataset/audio/mozk545b.mid'),
#  WindowsPath('../dataset/audio/mozk545c.mid'),
#  WindowsPath('../dataset/audio/mozk622a.mid'),
#  WindowsPath('../dataset/audio/mozk622b.mid'),
#  WindowsPath('../dataset/audio/mozk622c.mid'),
#  WindowsPath('../dataset/audio/mozsq1.mid'),
#  WindowsPath('../dataset/audio/moz_k191.mid'),
#  WindowsPath('../dataset/audio/moz_k299.mid'),
#  WindowsPath('../dataset/audio/mtmoz1.mid'),
#  WindowsPath('../dataset/audio/mzflqnar.mid'),
#  WindowsPath('../dataset/audio/mz_311_1.mid'),
#  WindowsPath('../dataset/audio/mz_311_2.mid'),
#  WindowsPath('../dataset/audio/mz_311_3.mid'),
#  WindowsPath('../dataset/audio/mz_330_1.mid'),
#  WindowsPath('../dataset/audio/mz_330_2.mid'),
#  WindowsPath('../dataset/audio/mz_330_3.mid'),
#  WindowsPath('../dataset/audio/mz_331_1.mid'),
#  WindowsPath('../dataset/audio/mz_331_2.mid'),
#  WindowsPath('../dataset/audio/mz_331_3.mid'),
#  WindowsPath('../dataset/audio/mz_332_1.mid'),
#  WindowsPath('../dataset/audio/mz_332_2.mid'),
#  WindowsPath('../dataset/audio/mz_332_3.mid'),
#  WindowsPath('../dataset/audio/mz_333_1.mid'),
#  WindowsPath('../dataset/audio/mz_333_2.mid'),
#  WindowsPath('../dataset/audio/mz_333_3.mid'),
#  WindowsPath('../dataset/audio/mz_545_1.mid'),
#  WindowsPath('../dataset/audio/mz_545_2.mid'),
#  WindowsPath('../dataset/audio/mz_545_3.mid'),
#  WindowsPath('../dataset/audio/mz_570_1.mid'),
#  WindowsPath('../dataset/audio/mz_570_2.mid'),
#  WindowsPath('../dataset/audio/mz_570_3.mid'),
#  WindowsPath('../dataset/audio/pianoconcertono21inCk4671andante.mid'),
#  WindowsPath('../dataset/audio/pianoconcertono21inCk4672andante .mid'),
#  WindowsPath('../dataset/audio/pianosonatano13inCk3331allegros.mid'),
#  WindowsPath('../dataset/audio/pianosonatano13inCk3332andante.mid'),
#  WindowsPath('../dataset/audio/pianosonatano13inCk3333allegretto.mid'),
#  WindowsPath('../dataset/audio/sym40-1.mid'),
#  WindowsPath('../dataset/audio/Symphony No. 41 in C, K.551, Jupiter.mid'),
#  WindowsPath('../dataset/audio/symphony_183_1_(c)ishii.mid'),
#  WindowsPath('../dataset/audio/symphony_183_2_(c)ishii.mid'),
#  WindowsPath('../dataset/audio/symphony_183_3_(c)ishii.mid'),
#  WindowsPath('../dataset/audio/themagicflutestevenritchie.mid')]

# %%
for i, mid in enumerate(dataset):
    print(f"==== Processing {i+1}/{len(dataset)} ====")
    encode(str(mid), print_details=False)
# Out:
# ==== Processing 1/182 ====
# Processing MIDI file: 11.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 11.86 minutes
# =======================================================
# Data saved to ../dataset/text\11_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 2/182 ====
# Processing MIDI file: 1584morzcondma.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 9.59 minutes
# =======================================================
# Data saved to ../dataset/text\1584morzcondma_1.txt
# with bpm = 78.0
# =======================================================
#
#
# ==== Processing 3/182 ====
# Processing MIDI file: 1763wamk465a.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 4
# Note: 1 instruments may use duplicate programs
# Estimated length: 13.53 minutes
# =======================================================
# Data saved to ../dataset/text\1763wamk465a_1.txt
# with bpm = 145.0
# =======================================================
#
#
# ==== Processing 4/182 ====
# Processing MIDI file: 1786gpk136a.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 10
# Note: 8 instruments may use duplicate programs
# Estimated length: 4.42 minutes
# =======================================================
# Data saved to ../dataset/text\1786gpk136a_1.txt
# with bpm = 126.0
# =======================================================
#
#
# ==== Processing 5/182 ====
# Processing MIDI file: 1787gpk136b.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 10
# Note: 8 instruments may use duplicate programs
# Estimated length: 4.45 minutes
# =======================================================
# Data saved to ../dataset/text\1787gpk136b_1.txt
# with bpm = 46.0
# =======================================================
#
#
# ==== Processing 6/182 ====
# Processing MIDI file: 1788gpk136c.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 10
# Note: 8 instruments may use duplicate programs
# Estimated length: 2.82 minutes
# =======================================================
# Data saved to ../dataset/text\1788gpk136c_1.txt
# with bpm = 146.0
# =======================================================
#
#
# ==== Processing 7/182 ====
# In d:\Codess & Projects\.venv\lib\site-packages\matplotlib\mpl-data\stylelib\grayscale.mplstyle: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=3, data=b'Sequence, YReid \xa92001'>; getting generic Instrument
# Processing MIDI file: 1996rondoflute.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 2
# All instruments have unique program assignments
# Estimated length: 5.48 minutes
# =======================================================
# Data saved to ../dataset/text\1996rondoflute_1.txt
# with bpm = 67.0
# =======================================================
#
#
# ==== Processing 8/182 ====
# Processing MIDI file: 2017mozk299no1.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 10
# Note: 3 instruments may use duplicate programs
# Estimated length: 9.28 minutes
# =======================================================
# Data saved to ../dataset/text\2017mozk299no1_1.txt
# with bpm = 116.0
# =======================================================
#
#
# ==== Processing 9/182 ====
# Processing MIDI file: 2018mozk299no2.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 7
# Note: 2 instruments may use duplicate programs
# Estimated length: 7.54 minutes
# =======================================================
# Data saved to ../dataset/text\2018mozk299no2_1.txt
# with bpm = 48.0
# =======================================================
#
#
# ==== Processing 10/182 ====
# Processing MIDI file: 2019mozk299no3.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 10
# Note: 3 instruments may use duplicate programs
# Estimated length: 10.44 minutes
# =======================================================
# Data saved to ../dataset/text\2019mozk299no3_1.txt
# with bpm = 140.5
# =======================================================
#
#
# ==== Processing 11/182 ====
# Processing MIDI file: 2021mozk191no1.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 9
# Note: 2 instruments may use duplicate programs
# Estimated length: 7.11 minutes
# =======================================================
# Data saved to ../dataset/text\2021mozk191no1_1.txt
# with bpm = 115.0
# =======================================================
#
#
# ==== Processing 12/182 ====
# Processing MIDI file: 2022mozk191no2.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 9
# Note: 2 instruments may use duplicate programs
# Estimated length: 5.57 minutes
# =======================================================
# Data saved to ../dataset/text\2022mozk191no2_1.txt
# with bpm = 38.0
# =======================================================
#
#
# ==== Processing 13/182 ====
# Processing MIDI file: 2023mozk191no3.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 9
# Note: 2 instruments may use duplicate programs
# Estimated length: 4.48 minutes
# =======================================================
# Data saved to ../dataset/text\2023mozk191no3_1.txt
# with bpm = 65.0
# =======================================================
#
#
# ==== Processing 14/182 ====
# Processing MIDI file: 2024panos3no1.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 13
# Note: 6 instruments may use duplicate programs
# Estimated length: 9.23 minutes
# =======================================================
# Data saved to ../dataset/text\2024panos3no1_1.txt
# with bpm = 128.0
# =======================================================
#
#
# ==== Processing 15/182 ====
# Processing MIDI file: 2025pianos3no2.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 13
# Note: 6 instruments may use duplicate programs
# Estimated length: 8.36 minutes
# =======================================================
# Data saved to ../dataset/text\2025pianos3no2_1.txt
# with bpm = 35.0
# =======================================================
#
#
# ==== Processing 16/182 ====
# Processing MIDI file: 2026pianos3no3.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 13
# Note: 6 instruments may use duplicate programs
# Estimated length: 5.62 minutes
# =======================================================
# Data saved to ../dataset/text\2026pianos3no3_1.txt
# with bpm = 146.5
# =======================================================
#
#
# ==== Processing 17/182 ====
# Processing MIDI file: 2029rondoSteven2.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 2
# Note: 1 instruments may use duplicate programs
# Estimated length: 7.41 minutes
# =======================================================
# Data saved to ../dataset/text\2029rondoSteven2_1.txt
# with bpm = 180.0
# =======================================================
#
#
# ==== Processing 18/182 ====
# Processing MIDI file: 2249phantasieSteven.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 2
# Note: 1 instruments may use duplicate programs
# Estimated length: 3.27 minutes
# =======================================================
# Data saved to ../dataset/text\2249phantasieSteven_1.txt
# with bpm = 100.0
# =======================================================
#
#
# ==== Processing 19/182 ====
# Processing MIDI file: 2250adagioSteven.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 2
# Note: 1 instruments may use duplicate programs
# Estimated length: 5.48 minutes
# =======================================================
# Data saved to ../dataset/text\2250adagioSteven_1.txt
# with bpm = 80.0
# =======================================================
#
#
# ==== Processing 20/182 ====
# Processing MIDI file: 2294rondomozSteven.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 2
# Note: 1 instruments may use duplicate programs
# Estimated length: 6.01 minutes
# =======================================================
# Data saved to ../dataset/text\2294rondomozSteven_1.txt
# with bpm = 95.0
# =======================================================
#
#
# ==== Processing 21/182 ====
# Processing MIDI file: 2344serenadeinbb.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 9
# Note: 2 instruments may use duplicate programs
# Estimated length: 4.06 minutes
# =======================================================
# Data saved to ../dataset/text\2344serenadeinbb_1.txt
# with bpm = 79.0
# =======================================================
#
#
# ==== Processing 22/182 ====
# Processing MIDI file: 240ALC~1.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 4
# Note: 3 instruments may use duplicate programs
# Estimated length: 8.31 minutes
# =======================================================
# Data saved to ../dataset/text\240ALC_1_1.txt
# with bpm = 132.0
# =======================================================
#
#
# ==== Processing 23/182 ====
# Processing MIDI file: 241Brondo.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 2
# Note: 1 instruments may use duplicate programs
# Estimated length: 5.47 minutes
# =======================================================
# Data saved to ../dataset/text\241Brondo_1.txt
# with bpm = 99.0
# =======================================================
#
#
# ==== Processing 24/182 ====
# Processing MIDI file: 2421mozartfunnya.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 2
# Note: 1 instruments may use duplicate programs
# Estimated length: 2.31 minutes
# =======================================================
# Data saved to ../dataset/text\2421mozartfunnya_1.txt
# with bpm = 114.0
# =======================================================
#
#
# ==== Processing 25/182 ====
# Processing MIDI file: 242Adag_bm.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 2
# Note: 1 instruments may use duplicate programs
# Estimated length: 11.94 minutes
# =======================================================
# Data saved to ../dataset/text\242Adag_bm_1.txt
# with bpm = 36.0
# =======================================================
#
#
# ==== Processing 26/182 ====
# Processing MIDI file: 244cosifn2t.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 12
# Note: 1 instruments may use duplicate programs
# Estimated length: 4.81 minutes
# =======================================================
# Data saved to ../dataset/text\244cosifn2t_1.txt
# with bpm = 80.0
# =======================================================
#
#
# ==== Processing 27/182 ====
# Processing MIDI file: 245div1.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 3
# Note: 1 instruments may use duplicate programs
# Estimated length: 7.89 minutes
# =======================================================
# Data saved to ../dataset/text\245div1_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 28/182 ====
# Processing MIDI file: 264diesirae.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 13
# Note: 7 instruments may use duplicate programs
# Estimated length: 1.83 minutes
# =======================================================
# Data saved to ../dataset/text\264diesirae_1.txt
# with bpm = 150.0
# =======================================================
#
#
# ==== Processing 29/182 ====
# Processing MIDI file: 2677mozartspring.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 3
# Note: 1 instruments may use duplicate programs
# Estimated length: 1.03 minutes
# =======================================================
# Data saved to ../dataset/text\2677mozartspring_1.txt
# with bpm = 117.0
# =======================================================
#
#
# ==== Processing 30/182 ====
# Processing MIDI file: 269Fantsy_c.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 12.13 minutes
# =======================================================
# Data saved to ../dataset/text\269Fantsy_c_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 31/182 ====
# Processing MIDI file: 29.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 4
# Note: 3 instruments may use duplicate programs
# Estimated length: 7.81 minutes
# =======================================================
# Data saved to ../dataset/text\29_1.txt
# with bpm = 164.0
# =======================================================
#
#
# ==== Processing 32/182 ====
# Processing MIDI file: 2916requm1.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 14
# Note: 2 instruments may use duplicate programs
# Estimated length: 5.16 minutes
# =======================================================
# Data saved to ../dataset/text\2916requm1_1.txt
# with bpm = 36.0
# =======================================================
#
#
# ==== Processing 33/182 ====
# Processing MIDI file: 2917requm2.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 10
# Note: 2 instruments may use duplicate programs
# Estimated length: 2.62 minutes
# =======================================================
# Data saved to ../dataset/text\2917requm2_1.txt
# with bpm = 88.0
# =======================================================
#
#
# ==== Processing 34/182 ====
# Processing MIDI file: 2918requm4.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 10
# Note: 3 instruments may use duplicate programs
# Estimated length: 5.88 minutes
# =======================================================
# Data saved to ../dataset/text\2918requm4_1.txt
# with bpm = 34.0
# =======================================================
#
#
# ==== Processing 35/182 ====
# Processing MIDI file: 3467minuetrdtevenritchie.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 2
# Note: 1 instruments may use duplicate programs
# Estimated length: 1.6 minutes
# =======================================================
# Data saved to ../dataset/text\3467minuetrdtevenritchie_1.txt
# with bpm = 90.0
# =======================================================
#
#
# ==== Processing 36/182 ====
# Processing MIDI file: 351fandm.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 5.37 minutes
# =======================================================
# Data saved to ../dataset/text\351fandm_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 37/182 ====
# d:\Codess & Projects\.venv\lib\site-packages\music21\midi\translate.py:922: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, data=b'Title: Ein Orgel-St\xfcck F\xfcr Ein Uhr in Abmaj (K. 608, 1791)'>; getting generic Instrument
#   warnings.warn(
# Processing MIDI file: 36.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 2
# Note: 1 instruments may use duplicate programs
# Estimated length: 8.91 minutes
# =======================================================
# Data saved to ../dataset/text\36_1.txt
# with bpm = 110.0
# =======================================================
#
#
# ==== Processing 38/182 ====
# Processing MIDI file: 362sonat_c1.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 2.3 minutes
# =======================================================
# Data saved to ../dataset/text\362sonat_c1_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 39/182 ====
# Processing MIDI file: 363sonat_c2.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 3.97 minutes
# =======================================================
# Data saved to ../dataset/text\363sonat_c2_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 40/182 ====
# Processing MIDI file: 364sonat_c3.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 1.43 minutes
# =======================================================
# Data saved to ../dataset/text\364sonat_c3_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 41/182 ====
# Processing MIDI file: 366fantsy_c.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 12.13 minutes
# =======================================================
# Data saved to ../dataset/text\366fantsy_c_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 42/182 ====
# Processing MIDI file: 367sonat_a1.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 7.47 minutes
# =======================================================
# Data saved to ../dataset/text\367sonat_a1_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 43/182 ====
# Processing MIDI file: 368sonat_a2.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 3.89 minutes
# =======================================================
# Data saved to ../dataset/text\368sonat_a2_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 44/182 ====
# Processing MIDI file: 369sonat_a3.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 2.93 minutes
# =======================================================
# Data saved to ../dataset/text\369sonat_a3_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 45/182 ====
# Processing MIDI file: 3954gloriainrstevenritchie.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 2
# Note: 1 instruments may use duplicate programs
# Estimated length: 4.26 minutes
# =======================================================
# Data saved to ../dataset/text\3954gloriainrstevenritchie_1.txt
# with bpm = 125.0
# =======================================================
#
#
# ==== Processing 46/182 ====
# Processing MIDI file: 4127mozsymphstevenritchie.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 2
# Note: 1 instruments may use duplicate programs
# Estimated length: 5.07 minutes
# =======================================================
# Data saved to ../dataset/text\4127mozsymphstevenritchie_1.txt
# with bpm = 140.0
# =======================================================
#
#
# ==== Processing 47/182 ====
# Processing MIDI file: 426mozfig.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 9
# Note: 1 instruments may use duplicate programs
# Estimated length: 4.8 minutes
# =======================================================
# Data saved to ../dataset/text\426mozfig_1.txt
# with bpm = 49.0
# =======================================================
#
#
# ==== Processing 48/182 ====
# Processing MIDI file: 4316mk387m4.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 4
# Note: 1 instruments may use duplicate programs
# Estimated length: 12.54 minutes
# =======================================================
# Data saved to ../dataset/text\4316mk387m4_1.txt
# with bpm = 180.0
# =======================================================
#
#
# ==== Processing 49/182 ====
# Processing MIDI file: 4317mk387m3.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 4
# Note: 1 instruments may use duplicate programs
# Estimated length: 5.33 minutes
# =======================================================
# Data saved to ../dataset/text\4317mk387m3_1.txt
# with bpm = 60.0
# =======================================================
#
#
# ==== Processing 50/182 ====
# Processing MIDI file: 4318mk387m2.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 4
# Note: 1 instruments may use duplicate programs
# Estimated length: 9.66 minutes
# =======================================================
# Data saved to ../dataset/text\4318mk387m2_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 51/182 ====
# Processing MIDI file: 4319mk387m1.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 4
# Note: 1 instruments may use duplicate programs
# Estimated length: 11.36 minutes
# =======================================================
# Data saved to ../dataset/text\4319mk387m1_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 52/182 ====
# Processing MIDI file: 4321_duett.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 14
# Note: 4 instruments may use duplicate programs
# Estimated length: 2.64 minutes
# =======================================================
# Data saved to ../dataset/text\4321_duett_1.txt
# with bpm = 135.0
# =======================================================
#
#
# ==== Processing 53/182 ====
# Processing MIDI file: 4498rmps04orig.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 10.64 minutes
# =======================================================
# Data saved to ../dataset/text\4498rmps04orig_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 54/182 ====
# Processing MIDI file: 4499rmps03orig.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 14.59 minutes
# =======================================================
# Data saved to ../dataset/text\4499rmps03orig_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 55/182 ====
# Processing MIDI file: 4500rmps02orig.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 17.55 minutes
# =======================================================
# Data saved to ../dataset/text\4500rmps02orig_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 56/182 ====
# Processing MIDI file: 4501rmps01orig.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 20.81 minutes
# =======================================================
# Data saved to ../dataset/text\4501rmps01orig_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 57/182 ====
# Processing MIDI file: 4502rmps05.mid
# -------------------------------------------------------
# Score title: None
# Total instruments detected: 1
# All instruments have unique program assignments
# Estimated length: 14.42 minutes
# =======================================================
# Data saved to ../dataset/text\4502rmps05_1.txt
# with bpm = 120.0
# =======================================================
#
#
# ==== Processing 58/182 ====
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\Codess & Projects\.venv\lib\site-packages\music21\stream\base.py in ?(self, element, returnSpecial)
#    2185             for idElement in self._offsetDict:  # slower search
#    2186                 o, returnedElement = self._offsetDict[idElement]
# -> 2187                 if element is returnedElement:
#    2188                     # MSC 2021 -- it is possible this no longer ever happens,
#
# KeyError: 2687273639392
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14720\3178734479.py in ?()
#       1 for i, mid in enumerate(dataset):
#       2     print(f"==== Processing {i+1}/{len(dataset)} ====")
# ----> 3     encode(str(mid), print_details=False)
#
# d:\Codess & Projects\Project Mozart\2) LLM part\encoder.py in ?(midi_path, output_dir, print_details)
#     385     # Ensure output directory exists
#     386     os.makedirs(output_dir, exist_ok=True)
#     387
#     388     # Extract song name (prefer metadata, fallback to filename)
# --> 389     score = converter.parse(midi_path)
#     390     name = None
#     391
#     392     if hasattr(score, 'metadata') and score.metadata and score.metadata.title:
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\converter\__init__.py in ?(value, forceSource, number, format, **keywords)
#    1403     elif not isinstance(value, bytes) and valueStr.startswith('MThd'):
#    1404         return parseData(value, number=number, format=format, **keywords)
#    1405     elif (not isinstance(value, bytes)
#    1406           and _osCanLoad(valueStr)):
# -> 1407         return parseFile(valueStr, number=number, format=format,
#    1408                          forceSource=forceSource, **keywords)
#    1409     elif (not isinstance(value, bytes)
#    1410           and _osCanLoad(common.cleanpath(valueStr))):
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\converter\__init__.py in ?(fp, number, format, forceSource, **keywords)
#    1258     Given a file path, attempt to parse the file into a Stream.
#    1259     '''
#    1260     v = Converter()
#    1261     fp = common.cleanpath(fp, returnPathlib=True)
# -> 1262     v.parseFile(fp, number=number, format=format, forceSource=forceSource, **keywords)
#    1263     if t.TYPE_CHECKING:
#    1264         assert isinstance(v.stream, (stream.Score, stream.Part, stream.Opus))
#    1265     return v.stream
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\converter\__init__.py in ?(self, fp, number, format, forceSource, storePickle, **keywords)
#     641             self.stream.metadata.fileNumber = number
#     642             self.stream.metadata.fileFormat = useFormat
#     643         else:
#     644             environLocal.printDebug('Loading original version')
# --> 645             self.parseFileNoPickle(fp, number, format, forceSource, **keywords)
#     646             if writePickle is True and fpPickle is not None and storePickle is True:
#     647                 # save the stream to disk
#     648                 environLocal.printDebug('Freezing Pickle')
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\converter\__init__.py in ?(self, fp, number, format, forceSource, **keywords)
#     568                 fp,
#     569                 number=number,
#     570                 **keywords
#     571             )
# --> 572         except NotImplementedError:
#     573             raise ConverterFileException(f'File is not in a correct format: {fp}')
#     574
#     575         if t.TYPE_CHECKING:
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\converter\subConverters.py in ?(self, filePath, number, encoding, **keywords)
#    1075         '''
#    1076         from music21.midi import translate as midiTranslate
#    1077         keywords = {k: v for k, v in self.keywords.items()
#    1078                     if k not in ('encoding',)}
# -> 1079         midiTranslate.midiFilePathToStream(
#    1080             filePath,
#    1081             inputM21=self.stream,
#    1082             encoding=encoding or self.encoding,
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\midi\translate.py in ?(filePath, inputM21, encoding, **keywords)
#    2831     mf = MidiFile()
#    2832     mf.open(filePath)
#    2833     mf.read()
#    2834     mf.close()
# -> 2835     return midiFileToStream(mf, inputM21=inputM21, encoding=encoding, **keywords)
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\midi\translate.py in ?(mf, inputM21, quantizePost, encoding, **keywords)
#    3000         raise exceptions21.StreamException('no tracks are defined in this MIDI file.')
#    3001
#    3002     # create a stream for each track
#    3003     # may need to check if tracks actually have event data
# -> 3004     midiTracksToStreams(mf.tracks,
#    3005                         ticksPerQuarter=mf.ticksPerQuarterNote,
#    3006                         quantizePost=quantizePost,
#    3007                         inputM21=s,
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\midi\translate.py in ?(midiTracks, ticksPerQuarter, quantizePost, inputM21, encoding, **keywords)
#    2738             s.insert(0, streamPart)
#    2739         else:
#    2740             streamPart = conductorPart
#    2741
# -> 2742         midiTrackToStream(mt,
#    2743                           ticksPerQuarter=ticksPerQuarter,
#    2744                           quantizePost=quantizePost,
#    2745                           inputM21=streamPart,
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\midi\translate.py in ?(mt, ticksPerQuarter, quantizePost, inputM21, conductorPart, isFirst, quarterLengthDivisors, encoding, **keywords)
#    2222             # Gaps will be filled by makeRests, below, which now recurses
#    2223             m.makeVoices(inPlace=True, fillGaps=False)
#    2224     s.makeTies(inPlace=True)
#    2225     # always need to fill gaps, as rests are not found in any other way
# -> 2226     s.makeRests(inPlace=True, fillGaps=True, timeRangeFromBarDuration=True)
#    2227     return s
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\stream\base.py in ?(self, refStreamOrTimeRange, fillGaps, timeRangeFromBarDuration, inPlace, hideRests)
#    6630         Calls :py:func:`~music21.stream.makeNotation.makeRests`.
#    6631
#    6632         * Changed in v7, inPlace=False by default.
#    6633         '''
# -> 6634         return makeNotation.makeRests(
#    6635             self,
#    6636             refStreamOrTimeRange=refStreamOrTimeRange,
#    6637             fillGaps=fillGaps,
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\stream\makeNotation.py in ?(s, refStreamOrTimeRange, fillGaps, timeRangeFromBarDuration, inPlace, hideRests)
#     894                 oHighTarget = oHighTargetForMeasure(m=maybe_measure, ts=refStreamOrTimeRange)
#     895         elif returnObj.hasMeasures():
#     896             # This could be optimized to save some context searches,
#     897             # but at the cost of readability.
# --> 898             oHighTarget = sum(
#     899                 m.barDuration.quarterLength for m in returnObj.getElementsByClass(stream.Measure)
#     900             )
#     901
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\stream\makeNotation.py in ?(.0)
#     898     def oHighTargetForMeasure(
# --> 899         m: stream.Measure|None = None,
#     900         ts: meter.TimeSignature|None = None
#     901     ) -> OffsetQL:
#     902         '''
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\stream\base.py in ?(self)
#   13368         #     as this search may take some time.
#   13369         if self.timeSignature is not None:
#   13370             ts = self.timeSignature
#   13371         else:  # do a context-based search
# > 13372             tsStream = self.getTimeSignatures(searchContext=True,
#   13373                                               returnDefault=False,
#   13374                                               sortByCreationTime=True)
#   13375             if not tsStream:
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\stream\base.py in ?(self, searchContext, returnDefault, recurse, sortByCreationTime)
#    5645
#    5646         # search activeSite Streams through contexts
#    5647         if not post and searchContext:
#    5648             # sort by time to search the most recent objects
# -> 5649             obj = self.getContextByClass('TimeSignature', sortByCreationTime=sortByCreationTime)
#    5650             # obj = self.previous(meter.TimeSignature)
#    5651             # environLocal.printDebug(['getTimeSignatures(): searching contexts: results', obj])
#    5652             if obj is not None:
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\base.py in ?(self, className, getElementMethod, sortByCreationTime, followDerivation, priorityTargetOnly)
#    1794
#    1795                 contextEl = payloadExtractor(site,
#    1796                                              flatten='semiFlat',
#    1797                                              innerPositionStart=positionStart)
# -> 1798                 if contextEl is not None and wellFormed(contextEl, site):
#    1799                     try:
#    1800                         site.coreSelfActiveSite(contextEl)
#    1801                     except SitesException:
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\base.py in ?(checkContextEl, checkSite)
#    1735             '''
#    1736             try:
#    1737                 selfSortTuple = self.sortTuple(checkSite, raiseExceptionOnMiss=True)
#    1738                 contextSortTuple = checkContextEl.sortTuple(checkSite, raiseExceptionOnMiss=True)
# -> 1739             except SitesException:
#    1740                 # might be raised by selfSortTuple; should not be by contextSortTuple.
#    1741                 # It just means that selfSortTuple isn't in the same stream
#    1742                 # as contextSortTuple, such as
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\base.py in ?(self, useSite, raiseExceptionOnMiss)
#    2747             foundOffset = self.offset
#    2748         else:
#    2749             try:
#    2750                 foundOffset = useSiteNoFalse.elementOffset(self, returnSpecial=True)
# -> 2751             except SitesException:
#    2752                 if raiseExceptionOnMiss:
#    2753                     raise
#    2754                 # environLocal.warn(r)
#
# d:\Codess & Projects\.venv\lib\site-packages\music21\stream\base.py in ?(self, element, returnSpecial)
#    2183             #    o = None  #  0 in TestStream -- not worth testing
#    2184         except KeyError:  # 445k - 442,443 = 3k in TestStream
#    2185             for idElement in self._offsetDict:  # slower search
#    2186                 o, returnedElement = self._offsetDict[idElement]
# -> 2187                 if element is returnedElement:
#    2188                     # MSC 2021 -- it is possible this no longer ever happens,
#    2189                     #    currently uncovered in Coverage.
#    2190                     break
#
# KeyboardInterrupt:
